# %% [markdown]
# # 03 - Visualization
# ===
#
# Spatial, temporal, and statistical visualizations.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from pathlib import Path
import warnings
warnings.filterwarnings('ignore')

plt.rcParams.update({'figure.dpi': 150, 'figure.figsize': (10, 6)})
sns.set_style('whitegrid')

DATA_DIR = Path('./data/processed')
OUTPUT_DIR = Path('./outputs/figures/visualization')
OUTPUT_DIR.mkdir(parents=True, exist_ok=True)

# %%
df = pd.read_parquet(DATA_DIR / 'ais_features.parquet')
print(f"Records: {len(df):,}")

# %% [markdown]
# ## Spatial Visualization

# %%
from src.visualization.spatial_viz import SpatialVisualizer

viz = SpatialVisualizer(str(OUTPUT_DIR))
# viz.plot_global_density_heatmap(df)  # Requires large sample
viz.plot_chokepoint_traffic(df.head(100000))
plt.show()

# %% [markdown]
# ## Temporal Visualization

# %%
from src.visualization.temporal_viz import TemporalVisualizer

viz = TemporalVisualizer(str(OUTPUT_DIR))
viz.plot_traffic_volume_timeseries(df)
plt.show()

# %% [markdown]
# ## Statistical Visualization

# %%
from src.visualization.statistical_viz import StatisticalVisualizer

viz = StatisticalVisualizer(str(OUTPUT_DIR))
viz.plot_correlation_heatmap(df)
viz.plot_feature_distributions(df)
plt.show()

# %% [markdown]
# ## Summary

# %%
print(f"Visualization complete! Output: {OUTPUT_DIR}")
